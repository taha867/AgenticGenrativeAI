# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
tool = TavilySearchResults(max_results=2)
results = tool.invoke({"query": 'ChatGPT version releases and updates from 2022 to 2026'})
results
# Out:
# /tmp/ipykernel_163842/1187185310.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tool = TavilySearchResults(max_results=2)
# [{'title': 'ChatGPT - Wikipedia',
#   'url': 'https://en.wikipedia.org/wiki/ChatGPT',
#   'content': '| Version | Release date | Status | Description |\n| GPT-3.5 | November 2022 | Discontinued | The first model used in ChatGPT. |\n| GPT-4 | March 2023 | Discontinued | Introduced in March 2023. |\n| GPT-4o | May 2024 | Discontinued | Capable of processing text, image, audio, and video, GPT-4o is faster and more capable than GPT-4. |\n| GPT-4o mini | July 2024 | Discontinued | A smaller and cheaper version of GPT-4o. GPT-4o mini replaced GPT-3.5 in the July 2024 version of ChatGPT. |\n| o1-preview | September 2024 | Discontinued | A pre-release version of OpenAI o1, an early reasoning model. |\n| o1-mini | September 2024 | Discontinued | A smaller and faster version of OpenAI o1. | [...] | o1 | December 2024 | Discontinued | The full release of OpenAI o1, which had previously been available as a preview. |\n| o1-pro | December 2024 | Discontinued | A version of o1 which uses more compute. |\n| o3-mini | January 2025 | Discontinued | Successor of o1-mini. |\n| o3-mini-high | January 2025 | Discontinued | Variant of o3-mini. |\n| GPT-4.5 | February 2025 | Discontinued | Particularly large GPT model. Promoted by Altman as OpenAI\'s "last non-chain-of-thought model". |\n| GPT-4.1 | April 2025 | Discontinued | First launched in the OpenAI API in April 2025, GPT-4.1 was later added to ChatGPT in May 2025. | [...] | GPT-4.1 mini | April 2025 | Discontinued | A smaller version of GPT-4.1. Originally launched in the OpenAI API in April 2025. GPT-4.1 mini replaced GPT-4o mini in the May 2025 version of ChatGPT. |\n| o3 | April 2025 | Legacy support | The full release of the o3 model, offering improved reasoning and performance compared to earlier "o" series models |\n| o4-mini | April 2025 | Discontinued | A compact version of the then-upcoming o4 model family. |\n| o4-mini-high | April 2025 | Discontinued | Variant of o4-mini intended to provide improved reliability. |\n| o3-pro | June 2025 | Discontinued | A version of o3 which uses more compute to get better results. |\n| GPT-5 | August 7, 2025 | Discontinued | Flagship model replacing all previous available models.[citation needed] |',
#   'score': 0.99988127},
#  {'title': 'OpenAI GPT & ChatGPT Timeline (2022 → Feb 2026) - LinkedIn',
#   'url': 'https://www.linkedin.com/pulse/openai-gpt-chatgpt-timeline-2022-feb-2026-sanjana-r-pmp-cspo--pxfoc',
#   'content': '### GPT-4.1 — April–May 2025\n\n   Released in the API in April 2025\n   Rolled out to paid ChatGPT users on May 14, 2025\n   Framed as a higher-precision, coding-optimized successor to GPT-4o\n   Improved instruction following and structured outputs\n\n  \n\n### GPT-4o / 4.1 Mini Lifecycle and Retirement\n\n### GPT-4.1 Mini & 4o Mini — May 2025\n\n   GPT-4.1 mini launched on May 14, 2025\n   Explicitly replaced GPT-4o mini in the ChatGPT model picker\n   Served as the fallback model for free users once GPT-4o usage limits were reached\n\n  \n\n### Ongoing GPT-4o Iterations (2024–2025)\n\n   GPT-4o received multiple incremental updates across:\n   These changes were documented in OpenAI’s model release notes rather than separate launches\n\n  \n\n### ChatGPT Retirement of 4-Series Models — February 13, 2026 [...] ### GPT-4 — March 2023\n\n   Officially announced by OpenAI in March 2023\n   Described as a larger, more capable multimodal model\n   Initially released via the API, followed shortly by availability in ChatGPT Plus\n   Focused on improved reasoning, instruction following, and reliability\n\n  \n\n### GPT-4o — May 2024\n\n   Introduced as a faster, cheaper, fully multimodal model\n   Supported text, vision, and later real-time voice\n   Positioned as the default GPT-4–level experience in ChatGPT\n   Emphasized reduced latency and more natural interaction\n\n  \n\n### GPT-4.1 — April–May 2025 [...] Language \n\n[](',
#   'score': 0.9995308}]

# %%
for r in results:
    print(r['content'])
# Out:
# | Version | Release date | Status | Description |
# | GPT-3.5 | November 2022 | Discontinued | The first model used in ChatGPT. |
# | GPT-4 | March 2023 | Discontinued | Introduced in March 2023. |
# | GPT-4o | May 2024 | Discontinued | Capable of processing text, image, audio, and video, GPT-4o is faster and more capable than GPT-4. |
# | GPT-4o mini | July 2024 | Discontinued | A smaller and cheaper version of GPT-4o. GPT-4o mini replaced GPT-3.5 in the July 2024 version of ChatGPT. |
# | o1-preview | September 2024 | Discontinued | A pre-release version of OpenAI o1, an early reasoning model. |
# | o1-mini | September 2024 | Discontinued | A smaller and faster version of OpenAI o1. | [...] | o1 | December 2024 | Discontinued | The full release of OpenAI o1, which had previously been available as a preview. |
# | o1-pro | December 2024 | Discontinued | A version of o1 which uses more compute. |
# | o3-mini | January 2025 | Discontinued | Successor of o1-mini. |
# | o3-mini-high | January 2025 | Discontinued | Variant of o3-mini. |
# | GPT-4.5 | February 2025 | Discontinued | Particularly large GPT model. Promoted by Altman as OpenAI's "last non-chain-of-thought model". |
# | GPT-4.1 | April 2025 | Discontinued | First launched in the OpenAI API in April 2025, GPT-4.1 was later added to ChatGPT in May 2025. | [...] | GPT-4.1 mini | April 2025 | Discontinued | A smaller version of GPT-4.1. Originally launched in the OpenAI API in April 2025. GPT-4.1 mini replaced GPT-4o mini in the May 2025 version of ChatGPT. |
# | o3 | April 2025 | Legacy support | The full release of the o3 model, offering improved reasoning and performance compared to earlier "o" series models |
# | o4-mini | April 2025 | Discontinued | A compact version of the then-upcoming o4 model family. |
# | o4-mini-high | April 2025 | Discontinued | Variant of o4-mini intended to provide improved reliability. |
# | o3-pro | June 2025 | Discontinued | A version of o3 which uses more compute to get better results. |
# | GPT-5 | August 7, 2025 | Discontinued | Flagship model replacing all previous available models.[citation needed] |
# ### GPT-4.1 — April–May 2025
#
#    Released in the API in April 2025
#    Rolled out to paid ChatGPT users on May 14, 2025
#    Framed as a higher-precision, coding-optimized successor to GPT-4o
#    Improved instruction following and structured outputs
#
#
#
# ### GPT-4o / 4.1 Mini Lifecycle and Retirement
#
# ### GPT-4.1 Mini & 4o Mini — May 2025
#
#    GPT-4.1 mini launched on May 14, 2025
#    Explicitly replaced GPT-4o mini in the ChatGPT model picker
#    Served as the fallback model for free users once GPT-4o usage limits were reached
#
#
#
# ### Ongoing GPT-4o Iterations (2024–2025)
#
#    GPT-4o received multiple incremental updates across:
#    These changes were documented in OpenAI’s model release notes rather than separate launches
#
#
#
# ### ChatGPT Retirement of 4-Series Models — February 13, 2026 [...] ### GPT-4 — March 2023
#
#    Officially announced by OpenAI in March 2023
#    Described as a larger, more capable multimodal model
#    Initially released via the API, followed shortly by availability in ChatGPT Plus
#    Focused on improved reasoning, instruction following, and reliability
#
#
#
# ### GPT-4o — May 2024
#
#    Introduced as a faster, cheaper, fully multimodal model
#    Supported text, vision, and later real-time voice
#    Positioned as the default GPT-4–level experience in ChatGPT
#    Emphasized reduced latency and more natural interaction
#
#
#
# ### GPT-4.1 — April–May 2025 [...] Language
#
# [](
