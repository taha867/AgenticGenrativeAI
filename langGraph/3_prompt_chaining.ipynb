# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatOpenAI()

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in Pakistan'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in Pakistan', 'outline': 'I. Introduction\n    A. Brief overview of AI\n    B. Explanation of the rise of AI globally\n    C. Transition into discussion of AI in Pakistan\n\nII. Background of AI in Pakistan\n    A. Overview of the current state of AI technology in Pakistan\n    B. Key players in the AI industry in Pakistan\n    C. Challenges faced in implementing AI in Pakistan\n\nIII. Applications of AI in Pakistan\n    A. AI in healthcare\n        1. Use of AI in diagnosing diseases\n        2. AI in personalized medicine\n    B. AI in agriculture\n        1. Use of AI in crop monitoring\n        2. AI in precision agriculture\n    C. AI in education\n        1. Use of AI in personalized learning\n        2. AI in virtual tutoring\n\nIV. Impact of AI on the economy of Pakistan\n    A. Job creation and displacement\n    B. Increased efficiency and productivity\n    C. Potential for economic growth through AI technologies\n\nV. Government initiatives and support for AI in Pakistan\n    A. Overview of government efforts to promote AI technology in Pakistan\n    B. Partnerships with international organizations\n    C. Investment in AI research and development\n\nVI. Challenges and opportunities for AI in Pakistan\n    A. Lack of skilled workforce\n    B. Data privacy and security concerns\n    C. Potential for AI to revolutionize key industries in Pakistan\n\nVII. Future outlook for AI in Pakistan\n    A. Predictions for the growth and evolution of AI technology in Pakistan\n    B. Opportunities for collaboration and innovation in the AI industry\n    C. Conclusion and call to action for further exploration of AI in Pakistan.', 'content': "\n\nI. Introduction\n\nIn recent years, artificial intelligence (AI) has emerged as a transformative technology with the potential to revolutionize various industries. From improving healthcare diagnostics to optimizing agricultural practices, AI is reshaping the way we work and live. Globally, countries are investing heavily in AI research and development to stay competitive in the digital age. Pakistan, too, is witnessing a rise in AI adoption across various sectors. This blog will delve into the background, applications, impact, government initiatives, challenges, and opportunities of AI in Pakistan.\n\nII. Background of AI in Pakistan\n\nPakistan has seen a surge in AI adoption in recent years, with various startups and tech companies working on innovative AI solutions. Key players in the AI industry in Pakistan include companies like AugmentCare, Cognitive Solutions, and Avanza Solutions. However, the adoption of AI technology in Pakistan is still in its nascent stages, with challenges such as lack of skilled workforce and infrastructure hindering its widespread implementation.\n\nIII. Applications of AI in Pakistan\n\nAI is being utilized in various sectors in Pakistan, including healthcare, agriculture, and education. In healthcare, AI is being used for disease diagnosis, personalized medicine, and telemedicine. In agriculture, AI is helping farmers optimize crop monitoring and implement precision agriculture techniques. In education, AI is being used for personalized learning and virtual tutoring, catering to individual student needs.\n\nIV. Impact of AI on the economy of Pakistan\n\nAI has the potential to significantly impact the economy of Pakistan by creating new job opportunities, increasing efficiency and productivity, and fostering economic growth through the adoption of AI technologies. However, there are concerns about job displacement due to automation, which need to be addressed through upskilling and reskilling programs.\n\nV. Government initiatives and support for AI in Pakistan\n\nThe government of Pakistan has been taking steps to promote AI technology in the country, including partnerships with international organizations and investment in AI research and development. Initiatives such as the National Center for Artificial Intelligence (NCAI) and th ...

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#     A. Brief overview of AI
#     B. Explanation of the rise of AI globally
#     C. Transition into discussion of AI in Pakistan
#
# II. Background of AI in Pakistan
#     A. Overview of the current state of AI technology in Pakistan
#     B. Key players in the AI industry in Pakistan
#     C. Challenges faced in implementing AI in Pakistan
#
# III. Applications of AI in Pakistan
#     A. AI in healthcare
#         1. Use of AI in diagnosing diseases
#         2. AI in personalized medicine
#     B. AI in agriculture
#         1. Use of AI in crop monitoring
#         2. AI in precision agriculture
#     C. AI in education
#         1. Use of AI in personalized learning
#         2. AI in virtual tutoring
#
# IV. Impact of AI on the economy of Pakistan
#     A. Job creation and displacement
#     B. Increased efficiency and productivity
#     C. Potential for economic growth through AI technologies
#
# V. Government initiatives and support for AI in Pakistan
#     A. Overview of government efforts to promote AI technology in Pakistan
#     B. Partnerships with international organizations
#     C. Investment in AI research and development
#
# VI. Challenges and opportunities for AI in Pakistan
#     A. Lack of skilled workforce
#     B. Data privacy and security concerns
#     C. Potential for AI to revolutionize key industries in Pakistan
#
# VII. Future outlook for AI in Pakistan
#     A. Predictions for the growth and evolution of AI technology in Pakistan
#     B. Opportunities for collaboration and innovation in the AI industry
#     C. Conclusion and call to action for further exploration of AI in Pakistan.

# %%
print(final_state['content'])
# Out:
# I. Introduction
#
# A. Artificial Intelligence (AI) is a branch of computer science that aims to create intelligent machines that can perform tasks that typically require human intelligence. These tasks can include speech recognition, decision-making, visual perception, and more.
#
# B. The field of AI has been steadily growing in India over the past few years, with advancements being made in various industries such as healthcare, finance, education, and more.
#
# C. The purpose of this blog is to explore the rise of AI in India and its implications on the economy, job market, society, and culture.
#
# II. Historical Context of AI in India
#
# A. India has a rich history in AI research, with institutions like the Indian Institute of Technology (IIT) and the Indian Statistical Institute (ISI) making significant contributions to the field.
#
# B. The Indian government has also taken steps to promote AI development in the country, with initiatives like the National AI Portal and the National Mission on Interdisciplinary Cyber-Physical Systems (NM-ICPS).
#
# C. The rise of AI startups in India has also been a key factor in driving innovation in the field, with companies like Flipkart, Zomato, and Ola using AI to improve their services.
#
# III. Current State of AI in India
#
# A. Major industries in India are leveraging AI technology to improve efficiency, reduce costs, and enhance customer experience. Industries like healthcare, fintech, and e-commerce are leading the way in AI adoption.
#
# B. Indian companies like Wipro, Infosys, and Tata Consultancy Services (TCS) are at the forefront of AI innovation, developing cutting-edge solutions for clients both in India and globally.
#
# C. The impact of AI on the Indian economy and job market has been significant, with AI creating new job opportunities in fields like data science, machine learning, and AI development.
#
# IV. Challenges and Opportunities
#
# A. Challenges faced by AI adoption in India include issues like data privacy, security concerns, and a lack of skilled professionals in the field.
#
# B. However, there are also many opportunities for growth and development in the AI sector, with the potential to create new revenue streams, improve efficiency, and drive innovation in various industries.
#
# C. The importance of AI education and skill development in India cannot be overstated, as a trained workforce is essential for the successful implementation of AI technologies.
#
# V. Future Outlook
#
# A. Predictions for the future of AI in India include continued growth in AI adoption across industries, with AI becoming an integral part of business operations in the country.
#
# B. Potential areas of growth and innovation in AI include the development of autonomous vehicles, AI-driven healthcare solutions, and personalized customer experiences.
#
# C. The implications of AI on society and culture in India are vast, with AI technology potentially changing the way we live, work, and interact with each other.
#
# VI. Conclusion
#
# A. In conclusion, the rise of AI in India presents both challenges and opportunities for the country, with the potential to drive economic growth, create new job opportunities, and improve the lives of citizens.
#
# B. It is important for readers to stay updated on AI developments in India and to continue learning about the field to fully understand its impact on society and the economy.
#
# C. As AI continues to evolve and grow in India, it is crucial for the country to embrace this technology and leverage its potential for the benefit of all.
